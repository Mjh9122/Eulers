# %%
import math
import numpy as np
from primefac import primefac

# %%
tris = []
for i in range(2, 1_000_000):
    tris.append(int(i * (i + 1) / 2))

primes = [list(set(primefac(i))) for i in tris]

# %%
len([tris[i] for i, j in enumerate(primes) if j[-1] >= 47])
# Out:
# 723836

# %%
print([tris[i] for i, j in enumerate(primes) if j[-1] < 47])
# Out:
# [3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210, 231, 253, 276, 300, 325, 351, 378, 406, 435, 465, 496, 528, 561, 595, 630, 666, 703, 741, 780, 820, 861, 903, 946, 990, 1035, 1081, 1176, 1225, 1275, 1326, 1378, 1485, 1540, 1596, 1653, 1711, 1770, 1830, 1891, 1953, 2016, 2080, 2145, 2211, 2346, 2415, 2485, 2628, 2701, 2775, 2850, 2926, 3003, 3240, 3321, 3486, 3570, 3655, 3741, 3828, 3916, 4005, 4095, 4186, 4278, 4371, 4560, 4656, 4753, 4851, 4950, 5050, 5460, 5565, 5778, 5995, 6105, 6216, 6328, 6441, 6555, 6670, 6786, 6903, 7021, 7140, 7260, 7626, 7750, 7875, 8001, 8256, 8385, 8515, 8778, 8911, 9045, 9180, 9453, 9591, 9730, 10296, 10440, 10585, 10731, 10878, 11628, 11781, 11935, 12090, 12720, 12880, 13041, 13530, 13695, 14028, 14196, 14365, 14535, 14706, 15225, 15400, 15576, 15753, 16110, 16471, 16653, 16836, 17020, 17205, 17391, 17766, 17955, 18528, 18915, 19110, 19306, 20100, 20503, 20706, 20910, 21321, 21528, 21736, 21945, 22155, 23005, 23220, 23436
# ...
